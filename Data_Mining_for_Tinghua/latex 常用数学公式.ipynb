# %% [markdown]
#  1.多行公式
#  \begin{equation}
#  f(x)=3x+1 \\
#  f(x)=2x+3
#  \end{equation}
#
#  \begin{eqnarray}
# \cos 2\theta & = & \cos^2 \theta - \sin^2 \theta \\
# & = & 2 \cos^2 \theta - 1.
# \end{eqnarray}
#
# \begin{equation}
# cos2\theta=\cos^2\theta-sin^2\theta
# \end{equation}
#
# 2.字符，若要使用数学环境中的字符，加\ ;上标^,下标_,上划线，下划线，向量，不等于 、希腊字母
# $$\sum_{i=1}^n a_{ij}=0$$
# $$\int_{0}^{\pi}$$
# $$\prod_{i=1}^{n}$$
# $$1\frac{1}{2}$$
# $$f(x)=x^{x^x}$$
# $$a\neq {b}$$
# $$\overline{m+n}$$
# $$\underline{m+n}$$
# $$\vec{a}$$
# $$\overrightarrow{AB}$$
# $$\hat{a}$$
# $$\breve{a}$$
# $$\grave{a}$$
# $$\bar{a}$$
# $$\alpha$$
# $$\beta$$
# $$\gamma$$
# $$\delta$$
# $$\theta$$
#
# 3.分数及开方、省略号
# + 分数 \frac{numerator}{denominator}
# + 开方 \sqrt{expression_r_r_r}表示开平方，\sqrt[n]{expression_r_r_r} 开n次方
# + 省略号 \ldots 文本底线对齐的省略号 ；\cdots 表示跟文本中线对齐的省略号
# $$\frac{n}{m}$$
# $$\sqrt{m}$$
# $$\sqrt[n]{m}$$
# $$f(x_1,x_x,\ldots,x_n) = x_1^2 + x_2^2 + \cdots + x_n^2 $$
#
# 4.大括号要用 \{ \}表示，在大括号中显示小括号要用\left( \right)
# $$\{f(x,y,z) = 3y^2 z [\left( |3| + \frac{7x+5}{1 + y^2} \right)].\}$$
#
# 5.导数、微分、极限、求和、积分
# $$\frac{\partial u}{\partial t}
# = h^2 ( \frac{\partial^2 u}{\partial x^2}
# + \frac{\partial^2 u}{\partial y^2}
# + \frac{\partial^2 u}{\partial z^2})$$
# $$\frac{du}{dx}|_{x=0}$$
# **微分的正确书写比较困哪**
# $$\left.\frac{du}{dx} \right|_{x=0}.$$
# $$\lim_{x \to +\infty}, \inf_{x > s}$$
# $$\lim_{x \to 0} \frac{3x^2 +7x^3}{x^2 +5x^4} = 3.$$
# **注意这里的\,dx**
# $$\int_a^b f(x)\,dx$$
# $$\int_0^1 \int_0^1 x^2 y^2\,dx\,dy$$
# $$\int \int_D f(x,y)\,dx\,dy$$
#
# 6.矩阵 行列式 方程组
#
# \begin{pmatrix} 0 & -i \\ i & 0 \end{pmatrix}
# \begin{vmatrix} a & b \\ c & d \end{vmatrix}
#
# **推荐使用这种方法**
# \begin{equation}       %开始数学环境
# \left(                 %左括号
#   \begin{array}{ccc}   %该矩阵一共3列，每一列都居中放置
#     a11 & a12 & a13\\  %第一行元素
#     a21 & a22 & a23\\  %第二行元素
#   \end{array}
# \right)                 %右括号
# \end{equation}
#
# \begin{equation}
# \left|
# \begin{array}{ccc}
# a11&a12&a13\\
# a21&a22&a23\\
# \end{array}
# \right|
# \end{equation}
#
# **推荐这个方法**
# $$ F=\left\{
# \begin{array}{lll}
# F_L       \\
# F^*_L     \\
# F^*_R     \\
# F_R
# \end{array} \right. $$
#
# $$ \left\{
# \begin{array}{lll}
# F_L = x+1      \\
# F^*_L =x+2    \\
# F^*_R  =x+3   \\
# F_R   =x+4
# \end{array} \right. $$
#
# $$ F=\left\{
# \begin{array}{rcl}
# F_L       &      & {0      <      S_L}\\
# F^*_L     &      & {S_L \leq 0 < S_M}\\
# F^*_R     &      & {S_M \leq 0 < S_R}\\
# F_R       &      & {S_R \leq 0}
# \end{array} \right. $$
#
#
#
#
#
# $$f(x)=
# \begin{cases}
# 0& \text{x=0}\\
# 1& \text{x!=0}
# \end{cases}$$
#
# $$ f(x)=\left\{
# \begin{aligned}
# x & = & \cos(t) \\
# y & = & \sin(t) \\
# z & = & \frac xy
# \end{aligned}
# \right.
# $$
